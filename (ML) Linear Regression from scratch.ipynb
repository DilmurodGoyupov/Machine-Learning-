# %% [markdown]
# # <center> <h1>    📈   🧑‍💻   📉

# %% [markdown]
#  # <center> Linear Regression - The goal of linear regression is to find the best line that fits the given points
#
#  * The blue line should be adjusted in such a way that the distance from it to the elements on both sides (functional poter, loss) should be as small as possible.

# %% [markdown]
# ![linear.jpg](attachment:linear.jpg)

# %% [markdown]
# The formula for linear regression is as follows
#
# # <center> <h1>  `y = ax + b`

# %% [markdown]
# `a = deflection coefficient (weight)`
#
# `b = point of intersection of the line with the y-axis (bias)`
#
# `x = ourpoints(data_x)`

# %% [markdown]
# We can find a and b by least mean square method and Gradient descent

# %% [markdown]
# # <center> Linear Regression.

# %% [markdown]
# ## <center> 1 - Least Mean Square Method

# %% [markdown]
# find the coefficient a.
#
# a = sum(from the current point x_train - the average of all x_trains is subtracted) * (from the current y_train - the average of all y_trains is subtracted) / sum(from the point x_train - the average of all x_trains is subtracted)**2
#
#
# ![lr11.png](attachment:lr11.png)
#
# Find the point of intersection (bias) of the b line with the y axis
#
# b = (average of all y_trains - a * y_train)

# %% [markdown]
# ![lr33.png](attachment:lr33.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# `We use a smaller dataset. Our dataset contains cars name, model, height, weight and CO2. In Linear we only use [Weight CO2] In Multi Linear we use [Volume Weight CO2].`

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
# Since we're only doing linear regression now, we'll only get the Weight and CO2 column
x = data[["Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
x
# Out:
# array([[ 790],
#        [1160],
#        [ 929],
#        [ 865],
#        [1140],
#        [ 929],
#        [1109],
#        [1365],
#        [1112],
#        [1150],
#        [ 980],
#        [ 990],
#        [1112],
#        [1252],
#        [1326],
#        [1330],
#        [1365],
#        [1280],
#        [1119],
#        [1328],
#        [1584],
#        [1428],
#        [1365],
#        [1415],
#        [1415],
#        [1465],
#        [1490],
#        [1725],
#        [1523],
#        [1705],
#        [1605],
#        [1746],
#        [1235],
#        [1390],
#        [1405],
#        [1395]], dtype=int64)

# %%
y
# Out:
# array([[ 99],
#        [ 95],
#        [ 95],
#        [ 90],
#        [105],
#        [105],
#        [ 90],
#        [ 92],
#        [ 98],
#        [ 99],
#        [ 99],
#        [101],
#        [ 99],
#        [ 94],
#        [ 97],
#        [ 97],
#        [ 99],
#        [104],
#        [104],
#        [105],
#        [ 94],
#        [ 99],
#        [ 99],
#        [ 99],
#        [ 99],
#        [102],
#        [104],
#        [114],
#        [109],
#        [114],
#        [115],
#        [117],
#        [104],
#        [108],
#        [109],
#        [120]], dtype=int64)

# %% [markdown]
# ![lr11.png](attachment:lr11.png)

# %%
def covariance(x,y):
    mx = x - x.mean()
    my = y - y.mean()
    
    covar = sum(mx * my)
    var = sum(mx**2)
    
    return covar / var

# %% [markdown]
# ![lr33.png](attachment:lr33.png)

# %%
def calculate(x,y):
    a = covariance(x,y)
    b = y.mean() - a * x.mean()
    return a,b

# %%
weight, bias = calculate(x,y)
weight, bias
# Out:
# (array([0.01699973]), array([80.05939852]))

# %%
# Now let's try to predict. So if the weight of the car is 790
weight * x[0] + bias
# 93.4 is predicted to come out
# Out:
# array([93.48918886])

# %% [markdown]
# #### We can know how good our prediction is by MSE(Mean squared error) or MAE(Mean absolute error)
#
# ![mse.png](attachment:mse.png)

# %% [markdown]
# ![mae.png](attachment:mae.png)

# %%
# predict
y_bash = weight * x + bias
y_bash
# Out:
# array([[ 93.48918886],
#        [ 99.77909066],
#        [ 95.85215197],
#        [ 94.76416895],
#        [ 99.43909597],
#        [ 95.85215197],
#        [ 98.9121042 ],
#        [103.26403626],
#        [ 98.9631034 ],
#        [ 99.60909332],
#        [ 96.71913843],
#        [ 96.88913578],
#        [ 98.9631034 ],
#        [101.34306625],
#        [102.60104661],
#        [102.66904554],
#        [103.26403626],
#        [101.81905881],
#        [ 99.08210154],
#        [102.63504607],
#        [106.98697813],
#        [104.33501954],
#        [103.26403626],
#        [104.11402299],
#        [104.11402299],
#        [104.96400972],
#        [105.38900308],
#        [109.38394071],
#        [105.94999432],
#        [109.04394602],
#        [107.34397256],
#        [109.74093514],
#        [101.05407076],
#        [103.68902962],
#        [103.94402564],
#        [103.77402829]])

# %%
mse = (y - y_bash)**2
mae = abs(y - y_bash)

# %%
sum(mse) / len(data)
# MSE
# Out:
# array([37.55581116])

# %%
sum(mae) / len(data)
# MAE
# Out:
# array([5.12155756])

# %% [markdown]
# ` The summary assessment is not good but our date and feauture are lacking. This is natural.`

# %%
import matplotlib.pyplot as plt

plt.xlabel('Weight')
plt.ylabel('CO2')
plt.scatter(x, y)
plt.plot(x, y_bash, color='red')

# %% [markdown]
# ##  <center> 2 - Multi Linear Regression

# %% [markdown]
# Multi Linear Regression is slightly different from linear. since we have a lot of x's, we work by matrix multiplication.
#
# ![lr55.png](attachment:lr55.png)

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
# we take Volume, Weight columns as x and CO2 column as y
x = data[["Volume", "Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
x
# Out:
# array([[1000,  790],
#        [1200, 1160],
#        [1000,  929],
#        [ 900,  865],
#        [1500, 1140],
#        [1000,  929],
#        [1400, 1109],
#        [1500, 1365],
#        [1500, 1112],
#        [1600, 1150],
#        [1100,  980],
#        [1300,  990],
#        [1000, 1112],
#        [1600, 1252],
#        [1600, 1326],
#        [1600, 1330],
#        [1600, 1365],
#        [2200, 1280],
#        [1600, 1119],
#        [2000, 1328],
#        [1600, 1584],
#        [2000, 1428],
#        [2100, 1365],
#        [1600, 1415],
#        [2000, 1415],
#        [1500, 1465],
#        [2000, 1490],
#        [2000, 1725],
#        [1600, 1523],
#        [2000, 1705],
#        [2100, 1605],
#        [2000, 1746],
#        [1600, 1235],
#        [1600, 1390],
#        [1600, 1405],
#        [2500, 1395]], dtype=int64)

# %%
y
# Out:
# array([[ 99],
#        [ 95],
#        [ 95],
#        [ 90],
#        [105],
#        [105],
#        [ 90],
#        [ 92],
#        [ 98],
#        [ 99],
#        [ 99],
#        [101],
#        [ 99],
#        [ 94],
#        [ 97],
#        [ 97],
#        [ 99],
#        [104],
#        [104],
#        [105],
#        [ 94],
#        [ 99],
#        [ 99],
#        [ 99],
#        [ 99],
#        [102],
#        [104],
#        [114],
#        [109],
#        [114],
#        [115],
#        [117],
#        [104],
#        [108],
#        [109],
#        [120]], dtype=int64)

# %%
#We find the average of column 1 of our x value.
x1_mean = x[:,0].mean()
x1_mean
# Out:
# 1611.111111111111

# %%
# We find the average of column 2 of our x value.
x2_mean = x[:,1].mean()
x2_mean
# Out:
# 1292.2777777777778

# %%
# We find the mean of the column of y
y_mean = y.mean()
y_mean
# Out:
# 102.02777777777777

# %%
x[:,0] = x[:,0] - x1_mean
# first, its average value is subtracted from the incoming x1 value

# %%
x[:,1] = x[:,1] - x2_mean
# second, its average value is subtracted from the incoming x2 value

# %%
y_var = y - y_mean
y_var
# third, its average value is subtracted from the y value
# Out:
# array([[ -3.02777778],
#        [ -7.02777778],
#        [ -7.02777778],
#        [-12.02777778],
#        [  2.97222222],
#        [  2.97222222],
#        [-12.02777778],
#        [-10.02777778],
#        [ -4.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -1.02777778],
#        [ -3.02777778],
#        [ -8.02777778],
#        [ -5.02777778],
#        [ -5.02777778],
#        [ -3.02777778],
#        [  1.97222222],
#        [  1.97222222],
#        [  2.97222222],
#        [ -8.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -0.02777778],
#        [  1.97222222],
#        [ 11.97222222],
#        [  6.97222222],
#        [ 11.97222222],
#        [ 12.97222222],
#        [ 14.97222222],
#        [  1.97222222],
#        [  5.97222222],
#        [  6.97222222],
#        [ 17.97222222]])

# %%
x
# Out:
# array([[-611, -502],
#        [-411, -132],
#        [-611, -363],
#        [-711, -427],
#        [-111, -152],
#        [-611, -363],
#        [-211, -183],
#        [-111,   72],
#        [-111, -180],
#        [ -11, -142],
#        [-511, -312],
#        [-311, -302],
#        [-611, -180],
#        [ -11,  -40],
#        [ -11,   33],
#        [ -11,   37],
#        [ -11,   72],
#        [ 588,  -12],
#        [ -11, -173],
#        [ 388,   35],
#        [ -11,  291],
#        [ 388,  135],
#        [ 488,   72],
#        [ -11,  122],
#        [ 388,  122],
#        [-111,  172],
#        [ 388,  197],
#        [ 388,  432],
#        [ -11,  230],
#        [ 388,  412],
#        [ 488,  312],
#        [ 388,  453],
#        [ -11,  -57],
#        [ -11,   97],
#        [ -11,  112],
#        [ 888,  102]], dtype=int64)

# %%
y_var
# Out:
# array([[ -3.02777778],
#        [ -7.02777778],
#        [ -7.02777778],
#        [-12.02777778],
#        [  2.97222222],
#        [  2.97222222],
#        [-12.02777778],
#        [-10.02777778],
#        [ -4.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -1.02777778],
#        [ -3.02777778],
#        [ -8.02777778],
#        [ -5.02777778],
#        [ -5.02777778],
#        [ -3.02777778],
#        [  1.97222222],
#        [  1.97222222],
#        [  2.97222222],
#        [ -8.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -3.02777778],
#        [ -0.02777778],
#        [  1.97222222],
#        [ 11.97222222],
#        [  6.97222222],
#        [ 11.97222222],
#        [ 12.97222222],
#        [ 14.97222222],
#        [  1.97222222],
#        [  5.97222222],
#        [  6.97222222],
#        [ 17.97222222]])

# %% [markdown]
# ![lr66.png](attachment:lr66.png)
#
# We multiply the x matrix that is the transpose by the x matrix. Then we get the inverse matrix.

# %%
inv_multiplication = np.linalg.inv(np.dot(x.T,x))
inv_multiplication
# Out:
# array([[ 4.37864453e-07, -5.30488284e-07],
#        [-5.30488284e-07,  1.13175024e-06]])

# %% [markdown]
# ![lr77.png](attachment:lr77.png)
#
# We multiply the value found above by Transpose x and y_var.

# %%
weights = inv_multiplication.dot(x.T).dot(y_var)
weights
# Out:
# array([[0.00780462],
#        [0.0075775 ]])

# %%
bias = y_mean - weights[0] * x1_mean - weights[1] * x2_mean
bias
# Out:
# array([79.6614231])

# %%
predict = weights[0] * 100 + weights[1]*790 + bias
predict
# Out:
# array([86.42811282])

# %%
y_hat = []
for i in range(len(x)):
    y_hat.append(sum(weights[0] * x[i][0] + weights[1]*x[i][1] + bias))

# %%
y_hat = np.array(y_hat)
y_hat
# Out:
# array([71.08889152, 75.45349237, 72.14216444, 70.87674188, 77.64332942,
#        72.14216444, 76.62796445, 79.34069008, 77.43115933, 78.49956682,
#        73.30907946, 74.94577923, 73.52884748, 79.27247212, 79.82562984,
#        79.85593985, 80.12115245, 84.1596118 , 78.26466422, 82.9548297 ,
#        81.78062561, 83.71258   , 84.01565968, 80.5000276 , 83.61407246,
#        80.09844038, 84.18238518, 85.96309838, 81.31839792, 85.81154832,
#        85.8342604 , 86.12222595, 79.14365457, 80.31059003, 80.42425257,
#        87.36483425])

# %%
y_hat = np.expand_dims(y_hat,1)
y_hat
# Out:
# array([[71.08889152],
#        [75.45349237],
#        [72.14216444],
#        [70.87674188],
#        [77.64332942],
#        [72.14216444],
#        [76.62796445],
#        [79.34069008],
#        [77.43115933],
#        [78.49956682],
#        [73.30907946],
#        [74.94577923],
#        [73.52884748],
#        [79.27247212],
#        [79.82562984],
#        [79.85593985],
#        [80.12115245],
#        [84.1596118 ],
#        [78.26466422],
#        [82.9548297 ],
#        [81.78062561],
#        [83.71258   ],
#        [84.01565968],
#        [80.5000276 ],
#        [83.61407246],
#        [80.09844038],
#        [84.18238518],
#        [85.96309838],
#        [81.31839792],
#        [85.81154832],
#        [85.8342604 ],
#        [86.12222595],
#        [79.14365457],
#        [80.31059003],
#        [80.42425257],
#        [87.36483425]])

# %%
y
# Out:
# array([[ 99],
#        [ 95],
#        [ 95],
#        [ 90],
#        [105],
#        [105],
#        [ 90],
#        [ 92],
#        [ 98],
#        [ 99],
#        [ 99],
#        [101],
#        [ 99],
#        [ 94],
#        [ 97],
#        [ 97],
#        [ 99],
#        [104],
#        [104],
#        [105],
#        [ 94],
#        [ 99],
#        [ 99],
#        [ 99],
#        [ 99],
#        [102],
#        [104],
#        [114],
#        [109],
#        [114],
#        [115],
#        [117],
#        [104],
#        [108],
#        [109],
#        [120]], dtype=int64)

# %%
mse = (y - y_hat)**2
mae = abs(y - y_hat)

# %%
sum(mse) / len(data)
# Out:
# array([534.09948559])

# %%
sum(mae) / len(data)
# Out:
# array([22.3699771])

# %% [markdown]
# ` The bottom line is not good. We'll see with SGD `

# %% [markdown]
# ## <center> 3- Linear Regression (SGD)

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
x = data[["Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
# we can normalize the data, because very large values may appear during the calculation process.
x = x/x.max()
x
# Out:
# array([[0.45246277],
#        [0.66437572],
#        [0.53207331],
#        [0.4954181 ],
#        [0.65292096],
#        [0.53207331],
#        [0.63516609],
#        [0.78178694],
#        [0.63688431],
#        [0.65864834],
#        [0.56128293],
#        [0.56701031],
#        [0.63688431],
#        [0.71706758],
#        [0.75945017],
#        [0.76174112],
#        [0.78178694],
#        [0.73310424],
#        [0.64089347],
#        [0.76059565],
#        [0.90721649],
#        [0.81786942],
#        [0.78178694],
#        [0.81042383],
#        [0.81042383],
#        [0.83906071],
#        [0.85337915],
#        [0.98797251],
#        [0.8722795 ],
#        [0.97651775],
#        [0.91924399],
#        [1.        ],
#        [0.70733104],
#        [0.79610538],
#        [0.80469645],
#        [0.79896907]])

# %%
# We also normalize y.
y = y / y.max()
y
# Out:
# array([[0.825     ],
#        [0.79166667],
#        [0.79166667],
#        [0.75      ],
#        [0.875     ],
#        [0.875     ],
#        [0.75      ],
#        [0.76666667],
#        [0.81666667],
#        [0.825     ],
#        [0.825     ],
#        [0.84166667],
#        [0.825     ],
#        [0.78333333],
#        [0.80833333],
#        [0.80833333],
#        [0.825     ],
#        [0.86666667],
#        [0.86666667],
#        [0.875     ],
#        [0.78333333],
#        [0.825     ],
#        [0.825     ],
#        [0.825     ],
#        [0.825     ],
#        [0.85      ],
#        [0.86666667],
#        [0.95      ],
#        [0.90833333],
#        [0.95      ],
#        [0.95833333],
#        [0.975     ],
#        [0.86666667],
#        [0.9       ],
#        [0.90833333],
#        [1.        ]])

# %%
lr = 0.001      # learning rate
epochs = 10000  # epochs
w = 0.8         # initial value of weight (we got random)
b = 0.5         # initial value of bias (we got random)

# %%
for epoch in range(epochs):
    for x_i, y_i in zip(x,y):
        
        y_bash = w*x_i + b
        
        loss = (y_i - y_bash)**2
        
        w = w - 0.001 * (2 * x_i * (y_bash - y_i))
        b = b - 0.001 * (2 * (y_bash - y_i))
        
        
    if epoch % 100 ==0:
        print(f"Epoch - {epoch}: Loss : {loss}")
        print("Weight = ",w, "  Bias = ", b)
# Out:
# Epoch - 0: Loss : [0.01268666]
# Weight =  [0.78705974]   Bias =  [0.48342962]
# Epoch - 100: Loss : [0.01356465]
# Weight =  [0.64535785]   Bias =  [0.36829327]
# Epoch - 200: Loss : [0.01392317]
# Weight =  [0.61255986]   Bias =  [0.39297377]
# Epoch - 300: Loss : [0.01425534]
# Weight =  [0.58248744]   Bias =  [0.41560603]
# Epoch - 400: Loss : [0.01456337]
# Weight =  [0.55491288]   Bias =  [0.43635842]
# Epoch - 500: Loss : [0.0148487]
# Weight =  [0.5296287]   Bias =  [0.45538709]
# Epoch - 600: Loss : [0.01511277]
# Weight =  [0.50644466]   Bias =  [0.47283521]
# Epoch - 700: Loss : [0.01535694]
# Weight =  [0.48518633]   Bias =  [0.48883406]
# Epoch - 800: Loss : [0.01558256]
# Weight =  [0.46569374]   Bias =  [0.50350402]
# Epoch - 900: Loss : [0.01579088]
# Weight =  [0.44782023]   Bias =  [0.51695548]
# Epoch - 1000: Loss : [0.01598311]
# Weight =  [0.43143133]   Bias =  [0.52928964]
# Epoch - 1100: Loss : [0.0161604]
# Weight =  [0.41640371]   Bias =  [0.5405993]
# ...

# %%
#prdict
lr = w*0.45246277+b
lr
# Out:
# array([0.77877394])

# %%
loss
#mse
# Out:
# array([0.01818159])

# %% [markdown]
# #### Linear regression is not bad via SGD

# %% [markdown]
# ## <center> 4 - Multi Linear Regression (SGD)

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
x = data[["Volume", "Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
x
# Out:
# array([[1000,  790],
#        [1200, 1160],
#        [1000,  929],
#        [ 900,  865],
#        [1500, 1140],
#        [1000,  929],
#        [1400, 1109],
#        [1500, 1365],
#        [1500, 1112],
#        [1600, 1150],
#        [1100,  980],
#        [1300,  990],
#        [1000, 1112],
#        [1600, 1252],
#        [1600, 1326],
#        [1600, 1330],
#        [1600, 1365],
#        [2200, 1280],
#        [1600, 1119],
#        [2000, 1328],
#        [1600, 1584],
#        [2000, 1428],
#        [2100, 1365],
#        [1600, 1415],
#        [2000, 1415],
#        [1500, 1465],
#        [2000, 1490],
#        [2000, 1725],
#        [1600, 1523],
#        [2000, 1705],
#        [2100, 1605],
#        [2000, 1746],
#        [1600, 1235],
#        [1600, 1390],
#        [1600, 1405],
#        [2500, 1395]], dtype=int64)

# %%
x1=[]
x2=[]

for i in range(len(x)):
    
    x1.append(x[i][0])
    x2.append(x[i][1])

# %%
x1 = x1/max(x1)
x1
# data normalization
# Out:
# array([0.4 , 0.48, 0.4 , 0.36, 0.6 , 0.4 , 0.56, 0.6 , 0.6 , 0.64, 0.44,
#        0.52, 0.4 , 0.64, 0.64, 0.64, 0.64, 0.88, 0.64, 0.8 , 0.64, 0.8 ,
#        0.84, 0.64, 0.8 , 0.6 , 0.8 , 0.8 , 0.64, 0.8 , 0.84, 0.8 , 0.64,
#        0.64, 0.64, 1.  ])

# %%
x2 = x1/max(x2)
x2
# data normalization
# Out:
# array([0.0002291 , 0.00027491, 0.0002291 , 0.00020619, 0.00034364,
#        0.0002291 , 0.00032073, 0.00034364, 0.00034364, 0.00036655,
#        0.000252  , 0.00029782, 0.0002291 , 0.00036655, 0.00036655,
#        0.00036655, 0.00036655, 0.00050401, 0.00036655, 0.00045819,
#        0.00036655, 0.00045819, 0.0004811 , 0.00036655, 0.00045819,
#        0.00034364, 0.00045819, 0.00045819, 0.00036655, 0.00045819,
#        0.0004811 , 0.00045819, 0.00036655, 0.00036655, 0.00036655,
#        0.00057274])

# %%
y = y / max(y)
y
# data normalization
# Out:
# array([[0.825     ],
#        [0.79166667],
#        [0.79166667],
#        [0.75      ],
#        [0.875     ],
#        [0.875     ],
#        [0.75      ],
#        [0.76666667],
#        [0.81666667],
#        [0.825     ],
#        [0.825     ],
#        [0.84166667],
#        [0.825     ],
#        [0.78333333],
#        [0.80833333],
#        [0.80833333],
#        [0.825     ],
#        [0.86666667],
#        [0.86666667],
#        [0.875     ],
#        [0.78333333],
#        [0.825     ],
#        [0.825     ],
#        [0.825     ],
#        [0.825     ],
#        [0.85      ],
#        [0.86666667],
#        [0.95      ],
#        [0.90833333],
#        [0.95      ],
#        [0.95833333],
#        [0.975     ],
#        [0.86666667],
#        [0.9       ],
#        [0.90833333],
#        [1.        ]])

# %%
w1=-2          # initial value of weight1 (we got random)
w2=3           # initial value of weight2 (we got random)

b1=1.5         # initial value of bias (we got random)

epochs=10000   # number of epochs

lr=0.001       # learning rate

# %%
for epoch in range(epochs):
    for x1_i, x2_i, y_i in zip(x1,x2,y):
        
        y_bash = w1*x1_i + w2*x2_i + b1
        
        loss = (y_i - y_bash)**2
        
        w1 = w1 - 0.001 * (2 * x1_i * (y_bash - y_i))
        w2 = w2 - 0.001 * (2 * x2_i * (y_bash - y_i))
        
        b1 = b1 - 0.001 * (2 * (y_bash - y_i))
       
        
        
    if epoch % 100 ==0:
        print(f"Epoch - {epoch}: Loss : {loss}")
        print("Weight = ",w1,w2, "  Bias = ", b1)
# Out:
# Epoch - 0: Loss : [2.03835948]
# Weight =  [-1.96789955] [3.00001839]   Bias =  [1.5441809]
# Epoch - 100: Loss : [0.42448728]
# Weight =  [-1.47507336] [3.00030065]   Bias =  [1.8244342]
# Epoch - 200: Loss : [0.34280691]
# Weight =  [-1.28253144] [3.00041092]   Bias =  [1.69765783]
# Epoch - 300: Loss : [0.2776396]
# Weight =  [-1.11165185] [3.00050879]   Bias =  [1.58512584]
# Epoch - 400: Loss : [0.2255504]
# Weight =  [-0.95998979] [3.00059565]   Bias =  [1.48524946]
# Epoch - 500: Loss : [0.18384808]
# Weight =  [-0.825384] [3.00067275]   Bias =  [1.39660541]
# Epoch - 600: Loss : [0.15040315]
# Weight =  [-0.7059163] [3.00074117]   Bias =  [1.31793049]
# Epoch - 700: Loss : [0.12352968]
# Weight =  [-0.59988422] [3.0008019]   Bias =  [1.24810353]
# Epoch - 800: Loss : [0.10189209]
# Weight =  [-0.50577676] [3.0008558]   Bias =  [1.18612948]
# Epoch - 900: Loss : [0.08443164]
# Weight =  [-0.42225285] [3.00090364]   Bias =  [1.13112518]
# Epoch - 1000: Loss : [0.07030841]
# ...

# %%
w1*0.45 + w2*0.0002291 + b1
# Out:
# array([0.80433689])

# %%
loss
#mse
# Out:
# array([0.00417298])

# %% [markdown]
# #### It also performed well in multi linear regression

# %% [markdown]
# ## <center> 5 - Linear Regression Sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
x = data[["Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
x
# Out:
# array([[ 790],
#        [1160],
#        [ 929],
#        [ 865],
#        [1140],
#        [ 929],
#        [1109],
#        [1365],
#        [1112],
#        [1150],
#        [ 980],
#        [ 990],
#        [1112],
#        [1252],
#        [1326],
#        [1330],
#        [1365],
#        [1280],
#        [1119],
#        [1328],
#        [1584],
#        [1428],
#        [1365],
#        [1415],
#        [1415],
#        [1465],
#        [1490],
#        [1725],
#        [1523],
#        [1705],
#        [1605],
#        [1746],
#        [1235],
#        [1390],
#        [1405],
#        [1395]], dtype=int64)

# %%
y
# Out:
# array([[ 99],
#        [ 95],
#        [ 95],
#        [ 90],
#        [105],
#        [105],
#        [ 90],
#        [ 92],
#        [ 98],
#        [ 99],
#        [ 99],
#        [101],
#        [ 99],
#        [ 94],
#        [ 97],
#        [ 97],
#        [ 99],
#        [104],
#        [104],
#        [105],
#        [ 94],
#        [ 99],
#        [ 99],
#        [ 99],
#        [ 99],
#        [102],
#        [104],
#        [114],
#        [109],
#        [114],
#        [115],
#        [117],
#        [104],
#        [108],
#        [109],
#        [120]], dtype=int64)

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# weight
# Out:
# array([[0.01699973]])

# %%
lr.intercept_
# bias
# Out:
# array([80.05939852])

# %%
lr.predict([[790]])
# The prognosis is not bad
# Out:
# array([[93.48918886]])

# %% [markdown]
# ## <center> 6 - Multi Linear Regression Sklearn

# %%
data = pd.read_csv("Datasets/datat.csv")
data
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
x = data[["Volume","Weight"]].to_numpy()
y = data[["CO2"]].to_numpy()

# %%
x
# Out:
# array([[1000,  790],
#        [1200, 1160],
#        [1000,  929],
#        [ 900,  865],
#        [1500, 1140],
#        [1000,  929],
#        [1400, 1109],
#        [1500, 1365],
#        [1500, 1112],
#        [1600, 1150],
#        [1100,  980],
#        [1300,  990],
#        [1000, 1112],
#        [1600, 1252],
#        [1600, 1326],
#        [1600, 1330],
#        [1600, 1365],
#        [2200, 1280],
#        [1600, 1119],
#        [2000, 1328],
#        [1600, 1584],
#        [2000, 1428],
#        [2100, 1365],
#        [1600, 1415],
#        [2000, 1415],
#        [1500, 1465],
#        [2000, 1490],
#        [2000, 1725],
#        [1600, 1523],
#        [2000, 1705],
#        [2100, 1605],
#        [2000, 1746],
#        [1600, 1235],
#        [1600, 1390],
#        [1600, 1405],
#        [2500, 1395]], dtype=int64)

# %%
y
# Out:
# array([[ 99],
#        [ 95],
#        [ 95],
#        [ 90],
#        [105],
#        [105],
#        [ 90],
#        [ 92],
#        [ 98],
#        [ 99],
#        [ 99],
#        [101],
#        [ 99],
#        [ 94],
#        [ 97],
#        [ 97],
#        [ 99],
#        [104],
#        [104],
#        [105],
#        [ 94],
#        [ 99],
#        [ 99],
#        [ 99],
#        [ 99],
#        [102],
#        [104],
#        [114],
#        [109],
#        [114],
#        [115],
#        [117],
#        [104],
#        [108],
#        [109],
#        [120]], dtype=int64)

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# weights
# Out:
# array([[0.00780526, 0.00755095]])

# %%
lr.intercept_
# bias
# Out:
# array([79.69471929])

# %%
lr.predict([[1000, 790]])
# The prognosis is not bad
# Out:
# array([[93.46522516]])

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
