# %% [markdown]
# # <center> <h1>    🍌 🧑‍💻 🍊

# %% [markdown]
# # <center> Naive Bayes classifier is an algorithm belonging to the family of classification algorithms. Each parameter of the data being classified is considered independently of other parameters of the class

# %% [markdown]
# ` Bayes theorem allows us to estimate a class based on a set of parameters using probabilities. `
#
# A simplified classification equation looks like this
#
# ![for1.png](attachment:for1.png)
#
# What does this equation mean?
#
# The equation finds the probability of class A based on the parameters Feature1 and Feature2.

# %% [markdown]
# In the photo part of the fraction (at the top of the fraction), we multiply the probability that parameter 1 belongs to class A, the probability that parameter 2 belongs to class A, and the probability of class A
#
# The denominator (bottom part) multiplies the probability of parameter 1 by the probability of parameter 2.

# %% [markdown]
# So we have the following dataset. Our dataset has a total of 1000 fruits. These are bananas, oranges and others. We have 3 parameters: yellow, sweet and long.
#
# ![Screenshot%202023-11-21%20153252.png](attachment:Screenshot%202023-11-21%20153252.png)

# %% [markdown]
# Looking at the table below, out of 500 bananas, 400 are long, 350 are sweet, and 450 are yellow. Out of 300 orange, 0 long, 150 sweet and 300 yellow. Of the remaining 200 fruits, 100 are long, 150 are sweet, and 50 are yellow.
#
# ![Screenshot%202023-11-21%20153342.png](attachment:Screenshot%202023-11-21%20153342.png)
#
# If we only get the length, sweetness, and color of the fruit from the parameters (without knowing its class), then we can calculate the probability that the fruit is a banana, an orange, or something else.

# %% [markdown]
# To calculate the probability that an unknown fruit is a banana, we first determine whether it is similar to a banana or not. The probability of the class "Banana" according to the parameters "long", "sweet", "yellow" is calculated as follows:
#
#
# ![Screenshot%202023-11-21%20153603.png](attachment:Screenshot%202023-11-21%20153603.png)
#
# Note that we always have the same denominator, so we can drop the denominator by adding proportionality to our formula. (To put it simply, the denominator is always the same value, so there is no problem if we drop the denominator when we divide the figure by the denominator)

# %% [markdown]
# ![Screenshot%202023-11-21%20154558.png](attachment:Screenshot%202023-11-21%20154558.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20153955.png](attachment:Screenshot%202023-11-21%20153955.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20154000.png](attachment:Screenshot%202023-11-21%20154000.png)

# %% [markdown]
# Let's condense the formula
#
# For the binary class
#
# ![for9.png](attachment:for9.png)

# %% [markdown]
# For many classes
#
# ![for10.png](attachment:for10.png)

# %% [markdown]
# First, a frequency table is created for each parameter with respect to the desired outcome. Probability tables are then constructed from the frequency tables, after which the probability for each class is calculated using the Bayes equation. The class with the highest probability will be the predicted result. Below are frequency tables and probability tables for all three classes.
#
#
# ![Screenshot%202023-11-21%20154227.png](attachment:Screenshot%202023-11-21%20154227.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20154233.png](attachment:Screenshot%202023-11-21%20154233.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20154240.png](attachment:Screenshot%202023-11-21%20154240.png)

# %% [markdown]
# Suppose we have an unknown fruit with parameters = short, sweet and yellow.
#
# *     Long parameter = NO because short
#
# *     Sweet parameter = YES because sweet
#
# *     Yellow parameter = YES because it is yellow
#
# ![Screenshot%202023-11-21%20154418.png](attachment:Screenshot%202023-11-21%20154418.png)
#
# `First we see the probability that an unknown fruit is a banana.`

# %% [markdown]
# ![Screenshot%202023-11-21%20154558.png](attachment:Screenshot%202023-11-21%20154558.png)

# %% [markdown]
# ![Screenshot%202023-11-21%20154656.png](attachment:Screenshot%202023-11-21%20154656.png)

# %% [markdown]
# ### `Let's check if our unknown fruit is a banana.`
#
# * 1. Unknown fruit length = short, so we calculate the value in our table 1
# ---------------
#
# * 2. Unknown fruit sweetness = sweet, so we calculate the value in our table 2
# ---------------
# * 3. Unknown fruit yellowness = yellow means we calculate the value in our table 3
# ---------------
# * 4 - We calculate the probability for the banana class.
#
# ![Screenshot%202023-11-21%20154950.png](attachment:Screenshot%202023-11-21%20154950.png)

# %%
# 1 - P(Length | Banana)
L_B = 100 / 500
L_B

# Number of bananas that are not 100 long
# 500 total number of bananas
# Out:
# 0.2

# %%
# 2 - P(Sweet | Banana)
S_B = 350 / 500
S_B

# 350 sweet bananas count
# 500 total number of bananas
# Out:
# 0.7

# %%
# 3 - P(Yellow | Banana)
Y_B = 450 / 500
Y_B

# 450 number of yellow bananas
# 500 total number of bananas
# Out:
# 0.9

# %%
# 4 - P(Banana)
P_B = 500 / 1000
P_B

# 500 total number of bananas
# 1000 total number of fruits
# Out:
# 0.5

# %%
# P(Banana | Length, Sweet, Yellow)
probability_of_being_banana = L_B * S_B * Y_B * P_B
probability_of_being_banana
# Out:
# 0.063

# %% [markdown]
# ` We've only considered the possibility of a banana, now we need to consider the possibility of an Orange.`
#
# ![Screenshot%202023-11-29%20120646.png](attachment:Screenshot%202023-11-29%20120646.png)

# %% [markdown]
# ### `Let's check if our unknown fruit is orange.`
#
# * 1. Unknown fruit length = short, so we calculate the value in our table 1
#
# ---------------
#
# * 2. Unknown fruit sweetness = sweet, so we calculate the value in our table 2
#
# ---------------
#
# * 3. Unknown fruit yellowness = yellow means we calculate the value in our table 3
#
# ---------------
#
# * 4. We calculate the probability of the orange class
#
#
# ![Screenshot%202023-11-29%20121100.png](attachment:Screenshot%202023-11-29%20121100.png)

# %%
# 1 - P(Length | Orange)
L_A = 300 / 300
L_A

# 300 is not the number of long oranges
# 300 total number of oranges
# Out:
# 1.0

# %%
# 2 - P(Sweet | Orange)
S_A = 150 / 300
S_A

# 150 number of sweet oranges
# 300 total number of oranges
# Out:
# 0.5

# %%
# 3 - P(Yellow | Orange)
Y_A = 300 / 300
Y_A

# 300 is the number of yellow oranges
# 300 total number of oranges
# Out:
# 1.0

# %%
# 4 - P(Orange)
P_A = 300 / 1000
P_A

# 300 total number of oranges
# 1000 total number of fruits
# Out:
# 0.3

# %%
# P(Banana | Length, Sweet, Yellow)
probability_of_being_orange = L_A * S_A * Y_A * P_A
probability_of_being_orange
# Out:
# 0.15

# %% [markdown]
# `We have considered the possibility of Bananas and Apples, now we need to consider the possibility of another fruit.`
#
# ![Screenshot%202023-11-29%20121611.png](attachment:Screenshot%202023-11-29%20121611.png)

# %% [markdown]
# ### `Let's check if our unknown fruit is another fruit. `
#
# * 1. Unknown fruit length = short, so we calculate the value in our table 1
#
# ---------------
#
# * 2. Unknown fruit sweetness = sweet, so we calculate the value in our table 2
#
# ---------------
#
# * 3. Unknown fruit yellowness = yellow means we calculate the value in our table 3
#
# ---------------
#
# * 4. We calculate the probability of another fruit class
#
# ![Screenshot%202023-11-29%20122132.png](attachment:Screenshot%202023-11-29%20122132.png)

# %%
# 1 - P(Length | Others)
L_A = 100 / 200
L_A

# 100 is the number of other fruits not long
# 200 total number of other fruits
# Out:
# 0.5

# %%
# 2 - P(Sweet | Others)
S_A = 150 / 200
S_A

# 150 number of sweet other fruits
# 200 total number of other fruits
# Out:
# 0.75

# %%
# 3 - P(Yellow | Others)
Y_A = 50 / 200
Y_A

# 50 is the number of yellow other fruits
# 200 total number of other fruits
# Out:
# 0.25

# %%
# 4 - P(Anothers)
P_A = 200 / 1000
P_A

# 200 total number of other fruits
# 1000 total number of fruits
# Out:
# 0.2

# %%
# P(Others | Length, Sweet, Yellow)
others_probability = L_A * S_A * Y_A * P_A
others_probability
# Out:
# 0.018750000000000003

# %%
print("Banana: ", probability_of_being_banana, ".  Orange: ", probability_of_being_orange, ".  Another fruits", others_probability)
print("Probabilities of being")
# Out:
# Banana:  0.063 .  Orange:  0.15 .  Another fruits 0.018750000000000003
# Probabilities of being

# %% [markdown]
# ### So our unknown fruit is most likely to be Orange.

# %% [markdown]
# ## <center> `Now let's see how we can predict if the values are continuous. Gauss will help us in this`

# %% [markdown]
# Naive Bayes Gaussian : All feature values are assumed to have a Gaussian distribution (normal distribution).
#
# ![EKw04RKWoAAF9ZF%281%29.jpg](attachment:EKw04RKWoAAF9ZF%281%29.jpg)

# %% [markdown]
# When drawn on a graph, a symmetrical curve should fit with respect to the average values of the parameters, as shown in the figure below.
#
#
# ![0%20go4jLX7V0wkyUsbG.jpg](attachment:0%20go4jLX7V0wkyUsbG.jpg)
#
# ` It is better to use Naive Bayes Gaussian if our values are continuous. `

# %% [markdown]
# The conditional probability for Naive Bayes Gaussian is defined as:
#
# ![0%209U2JnVY3iKtHwzCv.png](attachment:0%209U2JnVY3iKtHwzCv.png)

# %% [markdown]
# A complete view of our formula above.
#
# ![0%20drhzM095fcWl_1G8%281%29.jpg](attachment:0%20drhzM095fcWl_1G8%281%29.jpg)

# %% [markdown]
# So we have the following issue, where we have to decide whether to play football or not. Humidity is the only predictor here. Using this formula, knowing the mean and standard deviation, we can calculate the following probability:
#
#
# # <center> <h1>    ⚽️ 🧑‍💻 ⚽️
#
# ![Screenshot%202023-11-21%20150721.png](attachment:Screenshot%202023-11-21%20150721.png)

# %% [markdown]
# After we find the Mean and StdDev
#
# ![Screenshot%202023-11-21%20150836.png](attachment:Screenshot%202023-11-21%20150836.png)
#
# We can calculate the probability

# %% [markdown]
# ![Screenshot%202023-11-29%20125818.png](attachment:Screenshot%202023-11-29%20125818.png)

# %% [markdown]
# ### <center> ` So, when Humidity = 74, we are likely to play football !!!`

# %% [markdown]
# # <center> <h1> ⚽️ 👨‍💻   🚀
